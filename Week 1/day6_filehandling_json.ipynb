# %%
# Basic file handling demonstration(copied from chatgpt to understand stuff)

# Write to a file
with open("example.txt", "w") as f:
    f.write("This is the first line!\n")
    f.write("This is another line.")

# Read from a file
with open("example.txt", "r") as f:
    content = f.read()
    print("File contents:\n", content)

# Append new content
with open("example.txt", "a") as f:
    f.write("\nAppended line at the end!")

# Read again to check
with open("example.txt", "r") as f:
    print("\nAfter appending:\n", f.read())
# Out:
# File contents:
#  This is the first line!
# This is another line.
#
# After appending:
#  This is the first line!
# This is another line.
# Appended line at the end!

# %%
#Own prqactise to kinda learn a bit
with open("example.txt","a") as f:
    f.write("\nAnother line is added")
with open("example.txt", "r") as f:
    print("\nAfter appending result: ", f.read())
# Out:
# After appending result:  This is the first line!
# This is another line.
# Appended line at the end!
# Another line is added

# %%
#Ok so new stuff "json", idk what it is but it sounds scary lol
import json #Cause we dont have it here
"""Lets create a dictionary to store as the json"""
class_avgMarks = {"Science" : 87, "Maths" : 92, "English" : 86}
with open("Avg_marks.json", "w") as f:   #First we open the json(it creates it too)
    json.dump(class_avgMarks, f, indent=4)   #.dump adds the info
with open("Avg_marks.json", "r") as f:
    print(json.load(f))  #.load shows the info, mayb like loading stuff in game where load means output
#Kinda got it
# Out:
# {'Science': 87, 'Maths': 92, 'English': 86}
